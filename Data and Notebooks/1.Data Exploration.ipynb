# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Boston.csv')

# %% [markdown]
# What the Columns mean-
# 1. CRIM: per capita crime rate by town
# 2. ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS: proportion of non-retail business acres per town
# 4. CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# 5. NOX: nitric oxides concentration (parts per 10 million)
# 6. RM: average number of rooms per dwelling
# 7. AGE: proportion of owner-occupied units built prior to 1940
# 8. DIS: weighted distances to five Boston employment centres
# 9. RAD: index of accessibility to radial highways
# 10. TAX: full-value property-tax rate per 10,000 USD
# 11. PTRATIO: pupil-teacher ratio by town
# 12. B: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT: % lower status of the population
# 14. MEDV: Median value of owner-occupied homes in 1000 USD

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  BIAS_COL
# 0  396.90   4.98  24.0         1
# 1  396.90   9.14  21.6         1
# 2  392.83   4.03  34.7         1
# 3  394.63   2.94  33.4         1
# 4  396.90   5.33  36.2         1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
# CRIM        506 non-null float64
# ZN          506 non-null float64
# INDUS       506 non-null float64
# CHAS        506 non-null int64
# NOX         506 non-null float64
# RM          506 non-null float64
# AGE         506 non-null float64
# DIS         506 non-null float64
# RAD         506 non-null int64
# TAX         506 non-null int64
# PTRATIO     506 non-null float64
# B           506 non-null float64
# LSTAT       506 non-null float64
# MEDV        506 non-null float64
# BIAS_COL    506 non-null int64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %% [markdown]
# Let us try to understand our data, we will use various tools to understand our data. Diving deeper into our data helps us know what problems and challenges we have to solve.

# %%
import seaborn as sns

# %%
sns.distplot(data['CRIM'])

# %% [markdown]
# Per capita Crime Rate
#
# We see that crime rate is usually low, but in certain areas it goes high.

# %%
sns.distplot(data['ZN'])

# %% [markdown]
# Proportion of residential land zoned for lots over 25,000 sq.ft.

# %%
sns.distplot(data['NOX'])

# %% [markdown]
# Nitric oxides concentration (parts per 10 million)
#
# Nitric Oxide concentration might be an indicator of pollution. People might tend to prefer places with low pollution and hence high price for places with low Nitric Oxide Concentration. We see maximum concentration to be in distribution of 0.4-0.7 PPM.

# %%
sns.distplot(data['RM'])

# %% [markdown]
# Average number of rooms per dwelling
#
# Houses with more rooms might tend to be more costly. We see most houses have 5-7 rooms.

# %%
sns.distplot(data['AGE'])

# %% [markdown]
# Age of the House

# %%
sns.distplot(data['TAX'])

# %% [markdown]
# Full-value property-tax rate per 10,000 USD

# %%
sns.distplot(data['MEDV'])

# %% [markdown]
# Median value of owner-occupied homes in 1000 USD

# %% [markdown]
# Let us look at some scatter plots and try to understand relation between data.

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel("Median value of owner-occupied homes in 1000 USD")
plt.ylabel("Age of the House")
plt.scatter(data['MEDV'],data['AGE'],marker=".")

# %%
plt.xlabel("Median value of owner-occupied homes in 1000 USD")
plt.ylabel("Nitric oxides concentration (parts per 10 million)")
plt.scatter(data['MEDV'],data['NOX'],marker=".")

# %%
plt.xlabel("Median value of owner-occupied homes in 1000 USD")
plt.ylabel("Full-value property-tax rate per 10,000 USD")
plt.scatter(data['MEDV'],data['TAX'],marker=".")
